# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import KFold
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from src.utils import *

# %%
DATASET_1_TRAIN = "data/train/baseline_train.csv"
DATASET_1_VAL = "data/train/baseline_val.csv"

DATASET_2_TRAIN = "data/train/baseline-w-feature-eng_train.csv"
DATASET_2_VAL = "data/train/baseline-w-feature-eng_val.csv"

DATASET_3_TRAIN = "data/train/baseline-truncated_train.csv"
DATASET_3_VAL = "data/train/baseline-truncated_val.csv"

DATASET_4_TRAIN = "data/train/truncated-feat-eng_train.csv"
DATASET_4_VAL = "data/train/truncated-feat-eng_train.csv"

# %%
TRAIN_DATA = DATASET_4_TRAIN
VAL_DATA = DATASET_4_VAL

# %%
parameters = dict()
parameters['n_estimators'] = [10, 50, 100, 500]
parameters['learning_rate'] = [0.0001, 0.001, 0.01, 0.1, 1.0]
parameters['subsample'] = [0.5, 0.7, 1.0]
parameters['max_depth'] = [3, 7, 9]

# %%
train_set = pd.read_csv(TRAIN_DATA)
val_set = pd.read_csv(VAL_DATA)

X_train, y_train = split_features_and_monthly_rent_label(train_set)
X_test, y_test = split_features_and_monthly_rent_label(val_set)

# %%
model = GradientBoostingRegressor()
cv = KFold(n_splits=10)
grid_search = HalvingGridSearchCV(estimator=model, param_grid=parameters, n_jobs=-1, cv=cv, scoring='neg_root_mean_squared_error', verbose=3)
result = grid_search.fit(X_train, y_train)
# Out:
# n_iterations: 5
# n_required_iterations: 5
# n_possible_iterations: 5
# min_resources_: 666
# max_resources_: 54000
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 180
# n_resources: 666
# Fitting 10 folds for each of 180 candidates, totalling 1800 fits
# [CV 2/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.5;, score=(train=-703.997, test=-638.283) total time=   0.0s
# [CV 3/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.5;, score=(train=-700.154, test=-795.189) total time=   0.0s
# [CV 1/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.5;, score=(train=-708.825, test=-753.294) total time=   0.0s
# [CV 9/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.5;, score=(train=-735.330, test=-654.102) total time=   0.0s
# [CV 4/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.5;, score=(train=-726.652, test=-728.638) total time=   0.0s
# [CV 1/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.7;, score=(train=-708.821, test=-753.275) total time=   0.0s
# [CV 2/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.7;, score=(train=-703.992, test=-638.313) total time=   0.0s
# [CV 10/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.5;, score=(train=-690.441, test=-745.113) total time=   0.0s
# [CV 5/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.5;, score=(train=-703.616, test=-704.247) total time=   0.0s
# [CV 3/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.7;, score=(train=-700.134, test=-795.195) total time=   0.0s
# [CV 4/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.7;, score=(train=-726.654, test=-728.633) total time=   0.0s
# [CV 5/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.7;, score=(train=-703.623, test=-704.251) total time=   0.0s
# [CV 6/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.7;, score=(train=-681.269, test=-752.568) total time=   0.0s
# [CV 6/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.5;, score=(train=-681.273, test=-752.558) total time=   0.0s
# [CV 8/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.7;, score=(train=-703.103, test=-719.788) total time=   0.0s
# [CV 9/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.7;, score=(train=-735.325, test=-654.124) total time=   0.0s
# [CV 7/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.7;, score=(train=-675.091, test=-663.445) total time=   0.0s
# [CV 10/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.7;, score=(train=-690.435, test=-745.121) total time=   0.0s
# [CV 7/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.5;, score=(train=-675.090, test=-663.429) total time=   0.0s
# [CV 1/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=1.0;, score=(train=-708.825, test=-753.331) total time=   0.0s
# [CV 2/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=1.0;, score=(train=-703.988, test=-638.307) total time=   0.0s
# [CV 3/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=1.0;, score=(train=-700.123, test=-795.186) total time=   0.0s
# [CV 4/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=1.0;, score=(train=-726.653, test=-728.625) total time=   0.0s
# [CV 5/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=1.0;, score=(train=-703.613, test=-704.230) total time=   0.0s
# [CV 7/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=1.0;, score=(train=-675.087, test=-663.445) total time=   0.0s
# [CV 6/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=1.0;, score=(train=-681.265, test=-752.560) total time=   0.0s
# [CV 9/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=1.0;, score=(train=-735.318, test=-654.099) total time=   0.0s
# [CV 8/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=0.5;, score=(train=-703.111, test=-719.792) total time=   0.0s
# [CV 8/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=1.0;, score=(train=-703.100, test=-719.806) total time=   0.0s
# [CV 10/10] END learning_rate=0.0001, max_depth=3, n_estimators=10, subsample=1.0;, score=(train=-690.435, test=-745.091) total time=   0.0s
# [CV 1/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.5;, score=(train=-707.511, test=-751.880) total time=   0.0s
# [CV 2/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.5;, score=(train=-702.733, test=-637.293) total time=   0.1s
# [CV 5/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.5;, score=(train=-702.400, test=-703.052) total time=   0.0s
# [CV 4/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.5;, score=(train=-725.159, test=-727.140) total time=   0.0s
# [CV 3/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.5;, score=(train=-698.827, test=-793.995) total time=   0.1s
# [CV 6/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.5;, score=(train=-680.006, test=-751.119) total time=   0.0s
# [CV 7/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.5;, score=(train=-673.923, test=-662.250) total time=   0.0s
# [CV 8/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.5;, score=(train=-701.881, test=-718.775) total time=   0.1s
# [CV 9/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.5;, score=(train=-733.932, test=-652.784) total time=   0.1s
# [CV 10/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.5;, score=(train=-689.272, test=-744.045) total time=   0.1s
# [CV 5/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.7;, score=(train=-702.363, test=-703.015) total time=   0.0s
# [CV 3/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.7;, score=(train=-698.794, test=-794.037) total time=   0.1s
# [CV 4/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.7;, score=(train=-725.145, test=-727.058) total time=   0.1s
# [CV 2/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.7;, score=(train=-702.702, test=-637.262) total time=   0.1s
# [CV 1/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.7;, score=(train=-707.485, test=-751.929) total time=   0.1s
# [CV 6/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.7;, score=(train=-679.994, test=-751.112) total time=   0.1s
# [CV 7/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.7;, score=(train=-673.881, test=-662.198) total time=   0.0s
# [CV 9/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.7;, score=(train=-733.918, test=-652.643) total time=   0.0s
# [CV 8/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.7;, score=(train=-701.844, test=-718.754) total time=   0.0s
# [CV 1/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=1.0;, score=(train=-707.493, test=-752.137) total time=   0.1s
# [CV 5/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=1.0;, score=(train=-702.357, test=-702.951) total time=   0.1s
# [CV 3/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=1.0;, score=(train=-698.754, test=-793.944) total time=   0.1s
# [CV 7/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=1.0;, score=(train=-673.879, test=-662.184) total time=   0.1s
# [CV 9/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=1.0;, score=(train=-733.904, test=-652.624) total time=   0.1s
# [CV 10/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=0.7;, score=(train=-689.237, test=-744.018) total time=   0.1s
# [CV 1/10] END learning_rate=0.0001, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-705.816, test=-750.097) total time=   0.1s
# [CV 4/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=1.0;, score=(train=-725.151, test=-727.021) total time=   0.0s
# [CV 2/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=1.0;, score=(train=-702.709, test=-637.296) total time=   0.1s
# [CV 3/10] END learning_rate=0.0001, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-697.226, test=-792.561) total time=   0.1s
# [CV 6/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=1.0;, score=(train=-679.995, test=-751.127) total time=   0.1s
# [CV 10/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=1.0;, score=(train=-689.228, test=-743.822) total time=   0.1s
# [CV 8/10] END learning_rate=0.0001, max_depth=3, n_estimators=50, subsample=1.0;, score=(train=-701.844, test=-718.864) total time=   0.1s
# [CV 2/10] END learning_rate=0.0001, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-701.208, test=-636.047) total time=   0.1s
# [CV 5/10] END learning_rate=0.0001, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-700.853, test=-701.549) total time=   0.1s
# [CV 7/10] END learning_rate=0.0001, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-672.437, test=-660.699) total time=   0.1s
# [CV 4/10] END learning_rate=0.0001, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-723.307, test=-725.186) total time=   0.1s
# [CV 3/10] END learning_rate=0.0001, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-697.117, test=-792.513) total time=   0.1s
# [CV 9/10] END learning_rate=0.0001, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-732.145, test=-651.001) total time=   0.1s
# [CV 5/10] END learning_rate=0.0001, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-700.809, test=-701.478) total time=   0.1s
# [CV 1/10] END learning_rate=0.0001, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-705.809, test=-750.110) total time=   0.1s
# [CV 6/10] END learning_rate=0.0001, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-678.447, test=-749.426) total time=   0.1s
# [CV 7/10] END learning_rate=0.0001, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=

# [CV 7/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0;, score=(train=-485.113, test=-486.031) total time=   2.5s
# [CV 8/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0;, score=(train=-480.745, test=-501.671) total time=   2.5s
# [CV 7/10] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.5;, score=(train=-494.578, test=-489.001) total time=   7.3s
# [CV 8/10] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.5;, score=(train=-490.356, test=-506.041) total time=   7.2s
# [CV 10/10] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.5;, score=(train=-491.687, test=-491.432) total time=   7.0s
# [CV 9/10] END learning_rate=0.01, max_depth=3, n_estimators=500, subsample=0.5;, score=(train=-491.733, test=-499.910) total time=   7.2s
# [CV 1/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-479.507, test=-503.427) total time=   1.4s
# [CV 9/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0;, score=(train=-482.588, test=-494.196) total time=   2.4s
# [CV 2/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-480.368, test=-505.627) total time=   1.4s
# [CV 3/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-484.796, test=-468.981) total time=   1.4s
# [CV 4/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-483.786, test=-483.118) total time=   1.5s
# [CV 10/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0;, score=(train=-481.664, test=-485.391) total time=   2.5s
# [CV 5/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-481.826, test=-488.175) total time=   1.4s
# [CV 6/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-482.441, test=-489.228) total time=   1.4s
# [CV 7/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-484.137, test=-482.727) total time=   1.3s
# [CV 8/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-479.913, test=-500.609) total time=   1.4s
# [CV 9/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-481.964, test=-490.750) total time=   1.4s
# [CV 10/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-481.817, test=-487.826) total time=   1.4s
# [CV 1/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-479.552, test=-503.201) total time=   2.0s
# [CV 2/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-479.438, test=-504.564) total time=   1.9s
# [CV 3/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-485.078, test=-468.297) total time=   1.8s
# [CV 4/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-483.115, test=-481.208) total time=   1.9s
# [CV 5/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-480.132, test=-489.276) total time=   1.8s
# [CV 6/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-481.998, test=-489.264) total time=   1.8s
# [CV 7/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-484.325, test=-484.025) total time=   1.9s
# [CV 8/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-480.568, test=-501.674) total time=   1.8s
# [CV 9/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-481.872, test=-495.331) total time=   1.6s
# [CV 10/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-481.627, test=-486.905) total time=   1.6s
# ----------
# iter: 4
# n_candidates: 3
# n_resources: 53946
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [CV 7/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0;, score=(train=-486.182, test=-494.189) total time=   6.9s
# [CV 2/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0;, score=(train=-485.504, test=-503.653) total time=   7.0s
# [CV 6/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0;, score=(train=-486.933, test=-488.330) total time=   7.0s
# [CV 1/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0;, score=(train=-486.769, test=-493.603) total time=   7.1s
# [CV 3/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0;, score=(train=-487.391, test=-486.305) total time=   7.1s
# [CV 8/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0;, score=(train=-486.546, test=-493.577) total time=   7.1s
# [CV 4/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0;, score=(train=-486.690, test=-491.398) total time=   7.3s
# [CV 5/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0;, score=(train=-487.550, test=-484.151) total time=   7.2s
# [CV 3/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-487.172, test=-487.085) total time=   5.3s
# [CV 5/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-488.050, test=-483.585) total time=   5.2s
# [CV 2/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-484.978, test=-503.732) total time=   5.4s
# [CV 4/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-486.561, test=-491.591) total time=   5.3s
# [CV 10/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0;, score=(train=-486.730, test=-492.547) total time=   6.9s
# [CV 9/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=1.0;, score=(train=-487.591, test=-485.230) total time=   7.0s
# [CV 1/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-486.622, test=-493.491) total time=   7.1s
# [CV 6/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-486.920, test=-488.334) total time=   6.9s
# [CV 7/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-486.492, test=-494.870) total time=   5.3s
# [CV 9/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-487.568, test=-485.240) total time=   5.3s
# [CV 8/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-486.454, test=-492.678) total time=   5.4s
# [CV 10/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.7;, score=(train=-486.502, test=-491.820) total time=   5.4s
# [CV 2/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-484.688, test=-503.248) total time=   4.2s
# [CV 1/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-486.173, test=-492.911) total time=   4.2s
# [CV 3/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-487.350, test=-486.604) total time=   5.3s
# [CV 4/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-487.027, test=-491.508) total time=   5.6s
# [CV 6/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-486.918, test=-487.081) total time=   3.6s
# [CV 5/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-487.808, test=-483.267) total time=   3.7s
# [CV 7/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-486.350, test=-494.028) total time=   3.7s
# [CV 8/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-486.818, test=-492.598) total time=   3.6s
# [CV 9/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-487.764, test=-484.894) total time=   3.6s
# [CV 10/10] END learning_rate=0.1, max_depth=3, n_estimators=100, subsample=0.5;, score=(train=-486.689, test=-492.059) total time=   3.7s

# %%
grid_search_results = pd.DataFrame(result.cv_results_)
grid_search_results.describe()
# Out:
#              iter   n_resources  mean_fit_time  std_fit_time  mean_score_time  \
# count  270.000000    270.000000     270.000000    270.000000       270.000000
# mean     0.492593   2397.600000       0.731792      0.028337         0.002552
# std      0.830383   6241.666236       1.381653      0.062958         0.002676
# min      0.000000    666.000000       0.009054      0.000870         0.000812
# 25%      0.000000    666.000000       0.064467      0.007088         0.001192
# 50%      0.000000    666.000000       0.184377      0.013166         0.001565
# 75%      1.000000   1998.000000       0.720203      0.030707         0.002642
# max      4.000000  53946.000000       9.291524      0.695867         0.019956
#
#        std_score_time  split0_test_score  split1_test_score  \
# count      270.000000         270.000000         270.000000
# mean         0.001115        -632.127640        -619.600758
# std          0.001147         191.002404         224.069754
# min          0.000009       -2446.352411       -2290.260493
# 25%          0.000204        -731.532209        -635.851770
# 50%          0.000831        -566.452260        -557.189897
# 75%          0.001550        -519.004070        -515.952639
# max          0.006855        -436.648641        -474.624652
#
#        split2_test_score  split3_test_score  ...  split2_train_score  \
# count         270.000000         270.000000  ...        2.700000e+02
# mean         -664.184368        -634.800956  ...       -4.052329e+02
# std           189.065329         200.923474  ...        2.366940e+02
# min         -1871.464166       -1752.268109  ...       -7.001543e+02
# 25%          -777.286778        -709.349439  ...       -6.502882e+02
# 50%          -615.487781        -584.904752  ...       -4.636085e+02
# 75%          -530.185971        -514.750292  ...       -1.971773e+02
# max          -468.173663        -468.835227  ...       -1.330529e-08
#
#        split3_train_score  split4_train_score  split5_train_score  \
# count        2.700000e+02        2.700000e+02        2.700000e+02
# mean        -4.113735e+02       -4.101787e+02       -3.954666e+02
# std          2.450712e+02        2.370083e+02        2.318711e+02
# min         -7.266541e+02       -7.036231e+02       -6.812726e+02
# 25%         -6.727120e+02       -6.554200e+02       -6.328051e+02
# 50%         -4.564179e+02       -4.602356e+02       -4.591083e+02
# 75%         -1.951888e+02       -1.994137e+02       -1.846694e+02
# max         -1.383728e-08       -1.384624e-08       -1.356252e-08
#
#        split6_train_score  split7_train_score  split8_train_score  \
# count        2.700000e+02        2.700000e+02        2.700000e+02
# mean        -3.920169e+02       -4.063142e+02       -4.153103e+02
# std          2.288984e+02        2.372214e+02        2.485167e+02
# min         -6.750910e+02       -7.031115e+02       -7.353303e+02
# 25%         -6.275716e+02       -6.535992e+02       -6.813248e+02
# 50%         -4.475859e+02       -4.472835e+02       -4.517355e+02
# 75%         -1.930259e+02       -1.956786e+02       -1.907855e+02
# max         -1.353010e-08       -1.355654e-08       -1.373227e-08
#
#        split9_train_score  mean_train_score  std_train_score
# count          270.000000        270.000000       270.000000
# mean          -406.786634       -405.085412        11.286092
# std            230.277625        237.076076         8.467109
# min           -690.440993       -702.848984         0.608087
# 25%           -644.927523       -652.933828         5.944188
# 50%           -461.476438       -453.754579         9.981323
# 75%           -198.688559       -192.697580        15.830913
# max             -1.756163         -1.589038       100.095012
#
# [8 rows x 31 columns]

# %%
print(result.best_params_)
print(result.best_score_)
# Out:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
# -490.81988592003444

# %%
import joblib
joblib.dump(result, 'models/approach4_gb.pkl')
# Out:
# ['approach4_gb.pkl']

# %%
grid_search_model = joblib.load('models/approach4_gb.pkl')
grid_search_model.best_score_
# Out:
# -490.9728404556175

# %% [markdown]
# | Approach | Best RMSE | Best Params |
# |:--------|:--------|:--------|
# |1|487.26|learning_rate: 0.01, max_depth: 7, n_estimators: 500, subsample: 0.5|
# |2|490.85|learning_rate: 0.1, max_depth: 3, n_estimators: 100, subsample: 0.5|
# |3|491.55|learning_rate: 0.1, max_depth: 3, n_estimators: 100, subsample: 0.7|
# |4|490.97|learning_rate: 0.1, max_depth: 3, n_estimators: 100, subsample: 0.5|
